# %% [markdown]
# # Topology optimization of a permanent magnet
# In this example the topology of a permanent magnet with magnetization $\vec{M} = (0,0,M_z)$ is optimized to produce a maximum field in z-direction in a single point above the cubic design region.

# %% [markdown]
# ## Import libraries
# Import neccessary libraries and set backend to JAX and pyvisa rendering to static mode.

# %%
import jax
import jax.numpy as jnp
import pyvista as pv

import neuralmag as nm

nm.config.backend = "jax"
pv.set_jupyter_backend("static")
# Out:
# 2025-08-04 18:25:29 NeuralMag:INFO [NeuralMag] Version 0.9.2
# 2025-08-04 18:25:29 NeuralMag:INFO [NeuralMag] Backend set to 'jax'.

# %% [markdown]
# ## Create mesh and state
# Create state and set fixed magnetization in z-direction

# %%
mesh = nm.Mesh((20, 20, 12), (5e-9, 5e-9, 5e-9))
state = nm.State(mesh)

state.material.Ms = 1.0
state.m = nm.VectorFunction(state).fill((0, 0, 1))
# Out:
# 2025-08-04 18:25:30 NeuralMag:INFO [Mesh] 3D, 20 x 20 x 12 (size = 5e-09 x 5e-09 x 5e-09)
# 2025-08-04 18:25:30 NeuralMag:INFO [NeuralMag] Set default device to 'TFRT_CPU_0'.
# 2025-08-04 18:25:30 NeuralMag:INFO [NeuralMag] Set default dtype to 'float32'.
# 2025-08-04 18:25:30 NeuralMag:INFO [State] Running on device: TFRT_CPU_0 (dtype = float32, backend = jax)

# %% [markdown]
# ## Create dynamic attribute for material density $\rho(\vec{x})$
# We create a dynamical attribute `state.rho` that takes a scalar field `state.rho_m` and overrides the upper two layers of cells to be air.

# %%
state.rho = nm.CellFunction(
    state, tensor=lambda rho_m: rho_m.at[:, :, 10:].set(state.eps)
)
state.rho_m = nm.CellFunction(state).fill(1.0)

# %% [markdown]
# ## Setup demag field
# We set up the demag-field class, register it with the state and get a plain function for the demag-field computation with the masked material density `rho_m` as a first parameter.

# %%
demag = nm.DemagField().register(state, "demag")
demag_func = state.resolve("h_demag", ["rho_m"])
# Out:
# 2025-08-04 18:25:30 NeuralMag:INFO [DemagField] Register state methods (field: 'h_demag', energy: 'E_demag')
# 2025-08-04 18:25:30 NeuralMag:INFO [DemagField]: Set up demag tensor
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 demag = nm.DemagField().register(state, "demag")
# ----> 2 demag_func = state.resolve("h_demag", ["rho_m"])
#
# File ~/git/neuralmag/neuralmag/common/state.py:291, in State.resolve(self, func, func_args, remap, inject)
#     287     func = func.func
#     289 func = self.remap(func, remap)
# --> 291 subfunc_names, args = self._collect_func_deps(
#     292     func, exclude=func_args, remap=remap, inject=inject
#     293 )
#     294 name = func.__name__
#     295 name = "lmda" if func.__name__ == "<lambda>" else name
#
# File ~/git/neuralmag/neuralmag/common/state.py:240, in State._collect_func_deps(self, attr, exclude, remap, inject)
#     237 func_names = []
#     238 args = {}
#     239 for arg in set(
# --> 240     [remap.get(a, a) for a in inspect.signature(attr).parameters.keys()]
#     241 ) - set(exclude):
#     242     if arg in inject:
#     243         attr = inject[arg]
#
# File /usr/lib/python3.10/inspect.py:3254, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3252 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3253     """Get a signature object for the passed callable."""
# -> 3254     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3255                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/lib/python3.10/inspect.py:3002, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    2998 @classmethod
#    2999 def from_callable(cls, obj, *,
#    3000                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3001     """Constructs Signature for the given callable object."""
# -> 3002     return _signature_from_callable(obj, sigcls=cls,
#    3003                                     follow_wrapper_chains=follow_wrapped,
#    3004                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/lib/python3.10/inspect.py:2396, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2387 _get_signature_of = functools.partial(_signature_from_callable,
#    2388                             follow_wrapper_chains=follow_wrapper_chains,
#    2389                             skip_bound_arg=skip_bound_arg,
#    (...)
#    2392                             sigcls=sigcls,
#    2393                             eval_str=eval_str)
#    2395 if not callable(obj):
# -> 2396     raise TypeError('{!r} is not a callable object'.format(obj))
#    2398 if isinstance(obj, types.MethodType):
#    2399     # In this case we skip the first parameter of the underlying
#    2400     # function (usually `self` or `cls`).
#    2401     sig = _get_signature_of(obj.__func__)
#
# TypeError: <neuralmag.common.function.VectorFunction object at 0x7f991c4ae3e0> is not a callable object

# %% [markdown]
# ## Define loss function
# We define the loss function as negative absolute of the field's z-component in a central point above the design region $\vec{x}_0$
# $$J(\rho) = H_z^2(\rho^3 \vec{M}) |_{\vec{x} = \vec{x}_0}$$
# and compute the gradient function.

# %%
def loss(rho):
    return -(demag_func(rho**3)[10, 10, 12, 2] ** 2)


grad_loss = jax.grad(loss)

# %% [markdown]
# ## Optimization loop
# Perform the optimization loop by updating `rho_m` with the negative gradient and clip the values of `rho_m` to the interval [eps, 1].

# %%
learning_rate = 1e3

for i in range(100):
    grad = grad_loss(state.rho_m.tensor)
    state.rho_m.tensor = jnp.clip(
        state.rho_m.tensor - grad * learning_rate, state.eps, 1.0
    )

# %% [markdown]
# ## Write result and visualize

# %%
state.write_vti("rho", "topology-optimization/rho.vti")

mesh = pv.read("topology-optimization/rho.vti")
thresholded_mesh = mesh.threshold(value=0.5, scalars="rho")

plotter = pv.Plotter()
plotter.add_mesh(
    thresholded_mesh,
    color="white",
    lighting=True,
    smooth_shading=False,
    show_edges=True,
)
plotter.show()
